# %% [markdown]
# # Headline Text Analysis

# %% [markdown]
# ### Add Project Directory to Path

# %%
# Get the current working directory (where the notebook is running)
import os, sys
import pandas as pd
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import Modules

# %%
from script.headline_text_analyzer import HeadlineAnalyzer
analyzer = HeadlineAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Load Dataset

# %%
# Load news headline dataset
headline_df = pd.read_csv('data/raw_analyst_ratings.csv')

# %% [markdown]
# ## Dscriptive Statistics

# %% [markdown]
# **Setting up the date and time to Newyork's time(UTC-4)**

# %%
headline_df=analyzer.time_conversion(headline_df)
# Out:
# g:\Programming\10_Academy\Babi\week1\script\headline_text_analyzer.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time_only']=pd.to_datetime(df['time_only']).dt.time

# %% [markdown]
# ### Headline Length Distribution

# %%
analyzer.headline_length_plot(headline_df)

# %% [markdown]
# ### Count the number of articles per publisher to identify which publishers are most active

# %%
analyzer.publisher_count(headline_df)
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# MoneyGeek                 1
# muathe                    1
# Robert Morris             1
# LeftCoastHedgie           1
# Jeremie Capron            1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# ### Trends Over Time
# **Analyze the publication dates to see trends over time, such as increased news frequency on particular days or during specific events.**

# %%
analyzer.publication_freq_plot(headline_df)

# %% [markdown]
# ## Text Analysis(Sentiment analysis & Topic Modeling):

# %% [markdown]
# ### Sentiment Analysis

# %%
#calculating sentiment for each headline, catagorizing and plotting frequency distibution
analyzer.sentiment_analysis(headline_df)
# Out:
# sentiment
# Neutral          825174
# Positive         350496
# Negative         151648
# Very Positive     58949
# Very Negative     21061
# Name: count, dtype: int64

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ### Seasonal Decomposition

# %%
analyzer.time_series_analysis(headline_df)

# %% [markdown]
# ### Hourly Distribution

# %%
analyzer.hourly_distribution(headline_df)

# %%
#saving the sentiment score in separate data
headline_df.to_csv('data/sentiment_data.csv', index=False)

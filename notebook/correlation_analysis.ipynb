# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# ### Add Project Directory to Path

# %%
# Get the current working directory (where the notebook is running)
import os, sys
import pandas as pd
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import Modules

# %%
from script.correlation import CorrelationAnalyzer
analyzer=CorrelationAnalyzer()

# %% [markdown]
# ### Import Data

# %%
sentiment_data=pd.read_csv('data/sentiment_data.csv')
apple_stock_data=pd.read_csv('data/Output/apple_stock_data.csv')
amazon_stock_data=pd.read_csv('data/Output/amazon_stock_data.csv')
google_stock_data=pd.read_csv('data/Output/google_stock_data.csv')
tesla_stock_data=pd.read_csv('data/Output/tesla_stock_data.csv')
nvidia_stock_data=pd.read_csv('data/Output/nvidia_stock_data.csv')

# %% [markdown]
# ## Correlation for Apple

# %%
apple_aggregate=analyzer.correlation(sentiment_data,apple_stock_data,'AAPL')
# Out:
# Pearson correlation coefficient: 0.038281767857302

# %% [markdown]
# ### Plot Daily Return and Sentiment

# %%
analyzer.sentiment_vs_daily_return_plot(apple_aggregate)

# %% [markdown]
# ## Correlation for Google

# %%
google_aggregate=analyzer.correlation(sentiment_data,google_stock_data,'GOOG')
# Out:
# Pearson correlation coefficient: 0.18189737068641867

# %% [markdown]
# ### Plot Daily Return and Sentiment

# %%
analyzer.sentiment_vs_daily_return_plot(google_aggregate)

# %% [markdown]
# ## Correlation for Amazon

# %%
amazon_aggregate=analyzer.correlation(sentiment_data,amazon_stock_data,'AMZN')
# Out:
# Pearson correlation coefficient: 0.11949519173002604

# %% [markdown]
# ### Plot Daily Return and Sentiment

# %%
analyzer.sentiment_vs_daily_return_plot(amazon_aggregate)

# %% [markdown]
# ## Correlation for Tesla

# %%
tesla_aggregate=analyzer.correlation(sentiment_data,tesla_stock_data,'TSLA')
# Out:
# Pearson correlation coefficient: 0.15618571031234774

# %% [markdown]
# ### Plot Daily Return and Sentiment

# %%
analyzer.sentiment_vs_daily_return_plot(tesla_aggregate)

# %% [markdown]
# ## Correlation for NVIDIA

# %%
nvidia_aggregate=analyzer.correlation(sentiment_data,nvidia_stock_data,'TSLA')
# Out:
# Pearson correlation coefficient: 0.025039952402829503

# %% [markdown]
# ### Plot Daily Return and Sentiment

# %%
analyzer.sentiment_vs_daily_return_plot(nvidia_aggregate)
